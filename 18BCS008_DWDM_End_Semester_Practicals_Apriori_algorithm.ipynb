# %% [markdown]
# # Apriori algorithm

# %% [markdown]
# ### Dataset: Groceries dataset for Market Basket Analysis(MBA) (basket.csv)

# %%
#Importing the packages

import pandas as pd
from apyori import apriori

# %%
#Reading the dataset

data=pd.read_csv("basket.csv")
data
# Out:
#                            0                   1                    2       3  \
# 0                 whole milk              pastry          salty snack     NaN
# 1                    sausage          whole milk  semi-finished bread  yogurt
# 2                       soda  pickled vegetables                  NaN     NaN
# 3                canned beer     misc. beverages                  NaN     NaN
# 4                    sausage    hygiene articles                  NaN     NaN
# ...                      ...                 ...                  ...     ...
# 14958            butter milk  whipped/sour cream                  NaN     NaN
# 14959          bottled water               herbs                  NaN     NaN
# 14960  fruit/vegetable juice              onions                  NaN     NaN
# 14961           bottled beer    other vegetables                  NaN     NaN
# 14962                   soda     root vegetables  semi-finished bread     NaN
#
# ...

# %%
#Dataset description
#Number of rows and columns

data.shape
# Out:
# (14963, 11)

# %%
#Dataset description

data.describe()
# Out:
#                  0           1           2           3           4  \
# count        14963       14963        4883        2185         795
# unique         165         165         154         146         126
# top     whole milk  whole milk  whole milk  whole milk  whole milk
# freq          1083         983         244         111          39
#
#                     5       6           7              8     9          10
# count             451     276         196             51     1           1
# unique            101      88          72             35     1           1
# top     shopping bags  yogurt  whole milk  shopping bags  curd  newspapers
# freq               25      19          14              4     1           1

# %%
#Attributes and data types

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14963 entries, 0 to 14962
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       14963 non-null  object
#  1   1       14963 non-null  object
#  2   2       4883 non-null   object
#  3   3       2185 non-null   object
#  4   4       795 non-null    object
#  5   5       451 non-null    object
#  6   6       276 non-null    object
#  7   7       196 non-null    object
#  8   8       51 non-null     object
#  9   9       1 non-null      object
#  10  10      1 non-null      object
# dtypes: object(11)
# memory usage: 1.3+ MB

# %%
#Converting dataset into list

records_list=[]
for i in range(0,14963):
    records_list.append([str(data.values[i,j]) for j in range(0,11)])

# %%
#Transaction sets

for i in records_list:
    print(i)
# Out:
# ['whole milk', 'pastry', 'salty snack', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan']
# ['sausage', 'whole milk', 'semi-finished bread', 'yogurt', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan']
# ['soda', 'pickled vegetables', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan']
# ['canned beer', 'misc. beverages', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan']
# ['sausage', 'hygiene articles', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan']
# ['sausage', 'whole milk', 'rolls/buns', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan']
# ['whole milk', 'soda', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan']
# ['frankfurter', 'soda', 'whipped/sour cream', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan']
# ['frankfurter', 'curd', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan']
# ['beef', 'white bread', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan']
# ...

# %% [markdown]
# #### min support=0.5

# %%
#Apriori algorithm

association_rules1=apriori(records_list,min_support=0.5,min_confidence=0.7,min_length=2)

# %%
#Converting into list of association rules

association_rules_results1=list(association_rules1)

# %%
#Number of association rules

print(len(association_rules_results1))
# Out:
# 1

# %%
association_rules_results1[0]
# Out:
# RelationRecord(items=frozenset({'nan'}), support=0.9999331684822562, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'nan'}), confidence=0.9999331684822562, lift=1.0)])

# %%
#List of rules

for i in association_rules_results1:
    j=i[0]
    n=[m for m in j]
    print("Rule :"+str(i[0])+"->"+str(i[1]))
    print("Support : {}".format(i[1]))
    print("Confidence : {}".format(i[2][0][2]))
    print("Lift : {}".format(i[2][0][3]))
    print("\n------------------------------------------------\n")
# Out:
# Rule :frozenset({'nan'})->0.9999331684822562
# Support : 0.9999331684822562
# Confidence : 0.9999331684822562
# Lift : 1.0
#
# ------------------------------------------------

# %% [markdown]
# #### min support=0.005

# %%
#Apriori algorithm

association_rules2=apriori(records_list,min_support=0.005,min_confidence=0.7,min_length=2)

# %%
#Converting into list of association rules

association_rules_results2=list(association_rules2)

# %%
#Number of association rules

print(len(association_rules_results2))
# Out:
# 127

# %%
association_rules_results2[0]
# Out:
# RelationRecord(items=frozenset({'nan'}), support=0.9999331684822562, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'nan'}), confidence=0.9999331684822562, lift=1.0)])

# %%
#List of rules

for i in association_rules_results2:
    j=i[0]
    n=[m for m in j]
    print("Rule :"+str(i[0])+"->"+str(i[1]))
    print("Support : {}".format(i[1]))
    print("Confidence : {}".format(i[2][0][2]))
    print("Lift : {}".format(i[2][0][3]))
    print("\n------------------------------------------------\n")
# Out:
# Rule :frozenset({'nan'})->0.9999331684822562
# Support : 0.9999331684822562
# Confidence : 0.9999331684822562
# Lift : 1.0
#
# ------------------------------------------------
#
# Rule :frozenset({'UHT-milk', 'nan'})->0.021386085678005748
# Support : 0.021386085678005748
# Confidence : 1.0
# Lift : 1.000066835984494
#
# ------------------------------------------------
#
# Rule :frozenset({'nan', 'baking powder'})->0.008086613646995923
# Support : 0.008086613646995923
# Confidence : 1.0
# Lift : 1.000066835984494
#
# ------------------------------------------------
#
# Rule :frozenset({'nan', 'beef'})->0.03395041101383412
# Support : 0.03395041101383412
# Confidence : 1.0
# Lift : 1.000066835984494
#
# ------------------------------------------------
#
# Rule :frozenset({'berries', 'nan'})->0.021787074784468355
# Support : 0.021787074784468355
# Confidence : 1.0
# Lift : 1.000066835984494
#
# ------------------------------------------------
#
# ...
